# %% [markdown]
# <a href="https://colab.research.google.com/github/SUPRIYAPADHY/netflix-hompage/blob/main/credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importing the dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# !pip install pandas
import pandas as pd

# %%
# loading the dataset to a Pandas Dataframe
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 29794  35633  0.786689 -0.691214 -0.329291  0.149435  0.714779  1.949061
# 29795  35633  0.800996 -2.159993  0.008378 -1.081828 -1.768799 -0.445016
# 29796  35633  1.115726 -0.472602  0.983034  0.294673 -1.218768 -0.341755
# 29797  35634  1.239103 -1.000617  0.843324 -0.560021 -1.400343 -0.151696
# 29798  35634  1.374193 -0.720679  0.891375 -0.541402 -1.700000       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 29794 -0.136906  0.474172  0.206173  ... -0.165285 -0.793473 -0.030110
# 29795 -0.571165 -0.162429 -1.785636  ...  0.016930 -0.350492 -0.234889
# 29796 -0.667340  0.171155  0.805427  ...  0.104463  0.366801 -0.073219
# 29797 -1.026058 -0.001637 -0.131138  ...  0.325954  0.855203 -0.245683
# 29798       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
# dataset information
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29799 entries, 0 to 29798
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    29799 non-null  int64
#  1   V1      29799 non-null  float64
#  2   V2      29799 non-null  float64
#  3   V3      29799 non-null  float64
#  4   V4      29799 non-null  float64
#  5   V5      29799 non-null  float64
#  6   V6      29798 non-null  float64
#  7   V7      29798 non-null  float64
#  8   V8      29798 non-null  float64
#  9   V9      29798 non-null  float64
#  10  V10     29798 non-null  float64
#  11  V11     29798 non-null  float64
#  12  V12     29798 non-null  float64
#  13  V13     29798 non-null  float64
#  14  V14     29798 non-null  float64
#  15  V15     29798 non-null  float64
#  16  V16     29798 non-null  float64
#  17  V17     29798 non-null  float64
#  18  V18     29798 non-null  float64
#  19  V19     29798 non-null  float64
# ...

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transaction & fraudulent transaction
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    29704
# 1.0       94
# Name: count, dtype: int64

# %% [markdown]
# this dataset is highly unbalanced

# %% [markdown]
# 0 -->Normal Transactions
# 1 --> Fraudelent Transactions

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (29704, 31)
# (94, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    29704.000000
# mean        79.570030
# std        221.991154
# min          0.000000
# 25%          6.637500
# 50%         20.000000
# 75%         70.652500
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      94.000000
# mean       95.590000
# std       257.920621
# min         0.000000
# 25%         1.000000
# 50%         1.050000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    21422.566422 -0.184395  0.106639   0.759413  0.194690 -0.186422
# 1.0    19007.702128 -8.099702  6.084984 -11.565958  6.014185 -5.681925
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.096790 -0.096841  0.018203  0.361273  ...  0.044000 -0.035795
# 1.0   -2.370349 -7.912202  4.043743 -2.891421  ...  0.679513  0.573983
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.122933 -0.041017  0.010051  0.131937  0.022275  0.009773  0.004475
# 1.0   -0.380899 -0.338752 -0.258204  0.352443  0.183181  0.830627  0.101053
#
#          Amount
# Class
# 0.0    79.57003
# 1.0    95.59000
#
# [2 rows x 30 columns]

# %% [markdown]
# unders-Sampling

# %% [markdown]
# build a sample dataset containing similar distribution of normal transaction and fraudulent transactions
#
# number of fraudulent transactions --> 162

# %%
legit_sample = legit.sample(n=162)

# %% [markdown]
# concatenating 2 dataframes

# %%
new_dataset = pd.concat([legit_sample,fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 5225    5025  1.132376  0.122317  0.179001  0.413278  0.806393  1.569714
# 1558    1221 -2.574077  0.798899 -0.694405 -2.299404 -0.224491 -1.567267
# 24571  33285 -0.077988  0.068978  2.098552 -0.285910 -0.543529 -0.011127
# 11532  19905  1.284475 -0.528597 -0.551952 -1.692217  1.390419  3.487251
# 8973   12393 -7.301397 -1.332417 -1.404766  0.066377 -0.894556 -1.552134
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 5225  -0.386295  0.369732  1.377915  ... -0.343052 -0.594625  0.171249
# 1558  -0.005168  0.608422  0.724049  ...  0.023633  0.262818 -0.627974
# 24571  0.166202 -0.036343  0.795373  ... -0.083804  0.204928  0.191015
# 11532 -1.223489  0.875786  2.954982  ... -0.208136 -0.272552 -0.070785
# 8973  -0.053482  0.695295  3.315548  ... -1.357159  0.047638  1.430551
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 27362  34521  1.081234  0.416414  0.862919  2.520863 -0.005021  0.563341
# 27627  34634  0.333499  1.699873 -2.596561  3.643945 -0.585068 -0.654659
# 27738  34684 -2.439237  2.591458 -2.840126  1.286244 -1.777016 -1.436139
# 27749  34687 -0.860827  3.131790 -5.052968  5.420941 -2.494141 -1.811287
# 29687  35585 -2.019001  1.491270  0.005222  0.817253  0.973252 -0.639268
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 27362 -0.123372  0.223122 -0.673598  ... -0.159387 -0.305154  0.053620
# 27627 -2.275789  0.675229 -2.042416  ...  0.469212 -0.144363 -0.317981
# 27738 -2.206056 -2.282725 -0.292885  ...  1.774460 -0.771390  0.065727
# 27749 -5.479117  1.189472 -3.908206  ...  1.192694  0.090356 -0.341881
# 29687 -0.974073 -3.146929 -0.003159  ...  2.839596 -1.185443 -0.142812
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    162
# 1.0     94
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    20615.092593 -0.237829  0.070197   0.828157  0.118927 -0.193862
# 1.0    19007.702128 -8.099702  6.084984 -11.565958  6.014185 -5.681925
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.112636 -0.082309  0.059298  0.380785  ... -0.008758 -0.021203
# 1.0   -2.370349 -7.912202  4.043743 -2.891421  ...  0.679513  0.573983
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.156880 -0.070068  0.014133  0.074734 -0.000160  0.026454 -0.004212
# 1.0   -0.380899 -0.338752 -0.258204  0.352443  0.183181  0.830627  0.101053
#
#           Amount
# Class
# 0.0    80.009877
# 1.0    95.590000
#
# [2 rows x 30 columns]

# %% [markdown]
# splitting the data into features & targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 5225    5025  1.132376  0.122317  0.179001  0.413278  0.806393  1.569714
# 1558    1221 -2.574077  0.798899 -0.694405 -2.299404 -0.224491 -1.567267
# 24571  33285 -0.077988  0.068978  2.098552 -0.285910 -0.543529 -0.011127
# 11532  19905  1.284475 -0.528597 -0.551952 -1.692217  1.390419  3.487251
# 8973   12393 -7.301397 -1.332417 -1.404766  0.066377 -0.894556 -1.552134
# ...      ...       ...       ...       ...       ...       ...       ...
# 27362  34521  1.081234  0.416414  0.862919  2.520863 -0.005021  0.563341
# 27627  34634  0.333499  1.699873 -2.596561  3.643945 -0.585068 -0.654659
# 27738  34684 -2.439237  2.591458 -2.840126  1.286244 -1.777016 -1.436139
# 27749  34687 -0.860827  3.131790 -5.052968  5.420941 -2.494141 -1.811287
# 29687  35585 -2.019001  1.491270  0.005222  0.817253  0.973252 -0.639268
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(Y)
# Out:
# 5225     0.0
# 1558     0.0
# 24571    0.0
# 11532    0.0
# 8973     0.0
#         ...
# 27362    1.0
# 27627    1.0
# 27738    1.0
# 27749    1.0
# 29687    1.0
# Name: Class, Length: 256, dtype: float64

# %% [markdown]
# split th data into training data and testing data

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (256, 30) (204, 30) (52, 30)

# %% [markdown]
# Model  Training
#
#
#
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
# training the logistic regression model  with training data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation
#
# Accuracy Score

# %%
from sklearn.metrics import accuracy_score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9754901960784313

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy= accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9423076923076923
